# %% [markdown]
# <a href="https://colab.research.google.com/github/saiprasanthreddy/ml-things/blob/main/DBscan_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('/content/Mall_Customers.csv')
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x= dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=3,min_samples=4)

# %%
model = dbscan.fit(x)
labels = model.labels_

# %%
from sklearn import metrics

# %%
sample_cores = np.zeros_like(labels,dtype=bool)
sample_cores[dbscan.core_sample_indices_]=True

# %%
n_cluster = len(set(labels))-(1 if -1 in labels else 0)
n_cluster
# Out:
# 9

# %%
print(metrics.silhouette_score(x,labels))
# Out:
# -0.1908319132560097
